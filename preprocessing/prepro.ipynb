# %%
# %pip install matplotlib seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

csv_path = "misc/debate_17_3_05Feb2020.csv"

df=pd.read_csv(csv_path)
print(list(df["Speaker"]))
# Out:
# ['Preamble', 'SHRI ADHIR RANJAN CHOWDHURY (BAHARAMPUR)', 'SHRI ADHIR RANJAN CHOWDHURY', 'SHRI KODIKUNNIL SURESH (MAVELIKKARA)', 'SHRI ADHIR RANJAN CHOWDHURY', 'माननीय अध्यक्ष', 'माननीय अध्यक्ष', 'माननीय अध्यक्ष', 'श्री अधीर रंजन चौधरी', 'माननीय अध्यक्ष', 'SHRI ADHIR RANJAN CHOWDHURY', 'SHRI BHARTRUHARI MAHTAB (CUTTACK)', 'SHRI KODIKUNNIL SURESH', 'माननीय अध्यक्ष', 'श्री अधीर रंजन चौधरी', 'SHRI KODIKUNNIL SURESH', 'श्री भागीरथ चौधरी (अजमेर)', 'माननीय अध्यक्ष', 'श्री अधीर रंजन चौधरी', 'श्री अधीर रंजन चौधरी', 'श्री अधीर रंजन चौधरी', 'श्री अधीर रंजन चौधरी', 'माननीय अध्यक्ष', 'श्री अधीर रंजन चौधरी', 'SHRI BHARTRUHARI MAHTAB (CUTTACK)', 'SHRI ADHIR RANJAN CHOWDHURY', 'SHRI ANUBHAV MOHANTY (KENDRAPARA)', 'SHRI PRALHAD JOSHI', 'SHRI ANUBHAV MOHANTY', 'श्री अधीर रंजन चौधरी', 'माननीय अध्यक्ष', 'श्री अधीर रंजन चौधरी', 'माननीय अध्यक्ष', 'श्री अधीर रंजन चौधरी', 'माननीय अध्यक्ष', 'SHRI BHARTRUHARI MAHTAB', 'श्री प्रहलाद जोशी', 'माननीय अध्यक्ष', 'माननीय प्रधानमंत्री जी का यह मानना है कि संवाद , समन्वय और संवेदना की जो हमारी राष्ट्रीय परंपरा रही है , वही हमारे राष्ट्र का पथ प्रदर्शन करती रहेगी । * * श्री विष्णु दयाल राम ( पलामू )', 'श्री पी. पी. चौधरी (पाली)', 'HON. CHAIRPERSON', 'SHRI BHARTRUHARI MAHTAB', 'SHRI BHARTRUHARI MAHTAB', 'HON. CHAIRPERSON', 'SHRIMATI HARSIMRAT KAUR BADAL', 'श्रीमती हरसिमरत कौर बादल', 'SHRI BHARTRUHARI MAHTAB', 'SHRI BHARTRUHARI MAHTAB', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA (GUNTUR)', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'श्री हनुमान बेनीवाल (नागौर)', 'माननीय मंत्री जी , अर्जुन मेघवाल जी यहां बैठे हैं , आपके जिले में भी टिड्डी आई है , मेरे जिले में भी आई है । उसके बाद कृषि मंत्री जी को लेकर आप भी वहां जाएं । आप तमाम मंत्रियों को लेकर , सांसदों को लेकर वहां जाएं ।…(व्यवधान) श्री अर्जुन राम मेघवाल', 'श्री हनुमान बेनीवाल', 'माननीय सभापति', 'श्री हनुमान बेनीवाल', 'माननीय सभापति', 'श्री हनुमान बेनीवाल', 'माननीय सभापति', 'श्री हनुमान बेनीवाल', 'माननीय सभापति', 'श्री अच्युतानंद सामंत जी । प्रो.अच्युतानंद सामंत (कंधमाल)', 'HON. CHAIRPERSON', 'SHRI SRIDHAR KOTAGIRI (ELURU)', 'HON. CHAIRPERSON', 'SHRI SRIDHAR KOTAGIRI', 'HON. CHAIRPERSON', 'SHRI SRIDHAR KOTAGIRI', 'HON. CHAIRPERSON', 'SHRI SRIDHAR KOTAGIRI', 'माननीय राष्ट्रपति जी के अभिभाषण पर धन्यवाद प्रस्ताव का समर्थन करती हूँ । मैं माननीय राष्ट्रपति जी के अभिभाषण पर धन्यवाद प्रस्ताव का समर्थन करती हूँ । SHRIMATI SUPRIYA SADANAND SULE (BARAMATI)', 'SHRIMATI SUPRIYA SADANAND SULE', 'SHRIMATI SUPRIYA SADANAND SULE', 'श्रीमती सुप्रिया सदानंद सुले', 'श्री रामविलास पासवान', 'श्रीमती सुप्रिया सदानंद सुले', 'श्री रामविलास पासवान', 'श्रीमती सुप्रिया सदानंद सुले', 'माननीय सभापति', 'SHRIMATI SUPRIYA SULE', 'SHRI KIREN RIJIJU', 'SHRIMATI SUPRIYA SADANAND SULE', 'HON. CHAIRPERSON', 'SHRIMATI SUPRIYA SADANAND SULE', 'HON. CHAIRPERSON', 'SHRIMATI SUPRIYA SADANAND SULE', 'HON. CHAIRPERSON', 'SHRIMATI SUPRIYA SADANAND SULE', 'माननीय सभापति', 'माननीय सदस्यों से मेरा निवेदन है कि अपनी बात को पांच मिनट में समाप्त कीजिए । We have a very long list. … (Interruptions) सौगत राय जी , आप तो बहुत सीनियर लीडर हैं , आप बैठ जाइए । मैं सभी से दोबारा निवेदन करत ...

# %%
# To tackle the constituency based inconsistencies -> remove parantheses and everything inside them
import re
def remove_para_content(name:str)-> str:
    name = re.sub(r'\(.*?\)', '', name)
    return name
df["Speaker"] = df["Speaker"].apply(remove_para_content)
print(list(df["Speaker"]))
# Out:
# ['Preamble', 'SHRI ADHIR RANJAN CHOWDHURY ', 'SHRI ADHIR RANJAN CHOWDHURY', 'SHRI KODIKUNNIL SURESH ', 'SHRI ADHIR RANJAN CHOWDHURY', 'माननीय अध्यक्ष', 'माननीय अध्यक्ष', 'माननीय अध्यक्ष', 'श्री अधीर रंजन चौधरी', 'माननीय अध्यक्ष', 'SHRI ADHIR RANJAN CHOWDHURY', 'SHRI BHARTRUHARI MAHTAB ', 'SHRI KODIKUNNIL SURESH', 'माननीय अध्यक्ष', 'श्री अधीर रंजन चौधरी', 'SHRI KODIKUNNIL SURESH', 'श्री भागीरथ चौधरी ', 'माननीय अध्यक्ष', 'श्री अधीर रंजन चौधरी', 'श्री अधीर रंजन चौधरी', 'श्री अधीर रंजन चौधरी', 'श्री अधीर रंजन चौधरी', 'माननीय अध्यक्ष', 'श्री अधीर रंजन चौधरी', 'SHRI BHARTRUHARI MAHTAB ', 'SHRI ADHIR RANJAN CHOWDHURY', 'SHRI ANUBHAV MOHANTY ', 'SHRI PRALHAD JOSHI', 'SHRI ANUBHAV MOHANTY', 'श्री अधीर रंजन चौधरी', 'माननीय अध्यक्ष', 'श्री अधीर रंजन चौधरी', 'माननीय अध्यक्ष', 'श्री अधीर रंजन चौधरी', 'माननीय अध्यक्ष', 'SHRI BHARTRUHARI MAHTAB', 'श्री प्रहलाद जोशी', 'माननीय अध्यक्ष', 'माननीय प्रधानमंत्री जी का यह मानना है कि संवाद , समन्वय और संवेदना की जो हमारी राष्ट्रीय परंपरा रही है , वही हमारे राष्ट्र का पथ प्रदर्शन करती रहेगी । * * श्री विष्णु दयाल राम ', 'श्री पी. पी. चौधरी ', 'HON. CHAIRPERSON', 'SHRI BHARTRUHARI MAHTAB', 'SHRI BHARTRUHARI MAHTAB', 'HON. CHAIRPERSON', 'SHRIMATI HARSIMRAT KAUR BADAL', 'श्रीमती हरसिमरत कौर बादल', 'SHRI BHARTRUHARI MAHTAB', 'SHRI BHARTRUHARI MAHTAB', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA ', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'श्री हनुमान बेनीवाल ', 'माननीय मंत्री जी , अर्जुन मेघवाल जी यहां बैठे हैं , आपके जिले में भी टिड्डी आई है , मेरे जिले में भी आई है । उसके बाद कृषि मंत्री जी को लेकर आप भी वहां जाएं । आप तमाम मंत्रियों को लेकर , सांसदों को लेकर वहां जाएं ।… श्री अर्जुन राम मेघवाल', 'श्री हनुमान बेनीवाल', 'माननीय सभापति', 'श्री हनुमान बेनीवाल', 'माननीय सभापति', 'श्री हनुमान बेनीवाल', 'माननीय सभापति', 'श्री हनुमान बेनीवाल', 'माननीय सभापति', 'श्री अच्युतानंद सामंत जी । प्रो.अच्युतानंद सामंत ', 'HON. CHAIRPERSON', 'SHRI SRIDHAR KOTAGIRI ', 'HON. CHAIRPERSON', 'SHRI SRIDHAR KOTAGIRI', 'HON. CHAIRPERSON', 'SHRI SRIDHAR KOTAGIRI', 'HON. CHAIRPERSON', 'SHRI SRIDHAR KOTAGIRI', 'माननीय राष्ट्रपति जी के अभिभाषण पर धन्यवाद प्रस्ताव का समर्थन करती हूँ । मैं माननीय राष्ट्रपति जी के अभिभाषण पर धन्यवाद प्रस्ताव का समर्थन करती हूँ । SHRIMATI SUPRIYA SADANAND SULE ', 'SHRIMATI SUPRIYA SADANAND SULE', 'SHRIMATI SUPRIYA SADANAND SULE', 'श्रीमती सुप्रिया सदानंद सुले', 'श्री रामविलास पासवान', 'श्रीमती सुप्रिया सदानंद सुले', 'श्री रामविलास पासवान', 'श्रीमती सुप्रिया सदानंद सुले', 'माननीय सभापति', 'SHRIMATI SUPRIYA SULE', 'SHRI KIREN RIJIJU', 'SHRIMATI SUPRIYA SADANAND SULE', 'HON. CHAIRPERSON', 'SHRIMATI SUPRIYA SADANAND SULE', 'HON. CHAIRPERSON', 'SHRIMATI SUPRIYA SADANAND SULE', 'HON. CHAIRPERSON', 'SHRIMATI SUPRIYA SADANAND SULE', 'माननीय सभापति', 'माननीय सदस्यों से मेरा निवेदन है कि अपनी बात को पांच मिनट में समाप्त कीजिए । We have a very long list. …  सौगत राय जी , आप तो बहुत सीनियर लीडर हैं , आप बैठ जाइए । मैं सभी से दोबारा निवेदन करता हॅूं कि पांच मिनट में अपनी बात को समाप्त कीजिए । श्री चिराग कुमार पासवान ', 'माननीय सभापति', 'श्री चिराग कुमार पासवान', 'श्रीमती अनुप्रिया  ...

# %%
import re
def remove_long_pseudo_names(name:str)-> str:
    if not isinstance(name, str):
        return name
    if re.search(r"[A-Za-z]", name):
        name=name.upper()
    if len(name)>30:
        return None
    return name

df["Speaker"] = df["Speaker"].apply(remove_long_pseudo_names)
print(list(df["Speaker"]))
# Out:
# ['PREAMBLE', 'SHRI ADHIR RANJAN CHOWDHURY ', 'SHRI ADHIR RANJAN CHOWDHURY', 'SHRI KODIKUNNIL SURESH ', 'SHRI ADHIR RANJAN CHOWDHURY', 'माननीय अध्यक्ष', 'माननीय अध्यक्ष', 'माननीय अध्यक्ष', 'श्री अधीर रंजन चौधरी', 'माननीय अध्यक्ष', 'SHRI ADHIR RANJAN CHOWDHURY', 'SHRI BHARTRUHARI MAHTAB ', 'SHRI KODIKUNNIL SURESH', 'माननीय अध्यक्ष', 'श्री अधीर रंजन चौधरी', 'SHRI KODIKUNNIL SURESH', 'श्री भागीरथ चौधरी ', 'माननीय अध्यक्ष', 'श्री अधीर रंजन चौधरी', 'श्री अधीर रंजन चौधरी', 'श्री अधीर रंजन चौधरी', 'श्री अधीर रंजन चौधरी', 'माननीय अध्यक्ष', 'श्री अधीर रंजन चौधरी', 'SHRI BHARTRUHARI MAHTAB ', 'SHRI ADHIR RANJAN CHOWDHURY', 'SHRI ANUBHAV MOHANTY ', 'SHRI PRALHAD JOSHI', 'SHRI ANUBHAV MOHANTY', 'श्री अधीर रंजन चौधरी', 'माननीय अध्यक्ष', 'श्री अधीर रंजन चौधरी', 'माननीय अध्यक्ष', 'श्री अधीर रंजन चौधरी', 'माननीय अध्यक्ष', 'SHRI BHARTRUHARI MAHTAB', 'श्री प्रहलाद जोशी', 'माननीय अध्यक्ष', None, 'श्री पी. पी. चौधरी ', 'HON. CHAIRPERSON', 'SHRI BHARTRUHARI MAHTAB', 'SHRI BHARTRUHARI MAHTAB', 'HON. CHAIRPERSON', 'SHRIMATI HARSIMRAT KAUR BADAL', 'श्रीमती हरसिमरत कौर बादल', 'SHRI BHARTRUHARI MAHTAB', 'SHRI BHARTRUHARI MAHTAB', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA ', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI JAYADEV GALLA', 'श्री हनुमान बेनीवाल ', None, 'श्री हनुमान बेनीवाल', 'माननीय सभापति', 'श्री हनुमान बेनीवाल', 'माननीय सभापति', 'श्री हनुमान बेनीवाल', 'माननीय सभापति', 'श्री हनुमान बेनीवाल', 'माननीय सभापति', None, 'HON. CHAIRPERSON', 'SHRI SRIDHAR KOTAGIRI ', 'HON. CHAIRPERSON', 'SHRI SRIDHAR KOTAGIRI', 'HON. CHAIRPERSON', 'SHRI SRIDHAR KOTAGIRI', 'HON. CHAIRPERSON', 'SHRI SRIDHAR KOTAGIRI', None, 'SHRIMATI SUPRIYA SADANAND SULE', 'SHRIMATI SUPRIYA SADANAND SULE', 'श्रीमती सुप्रिया सदानंद सुले', 'श्री रामविलास पासवान', 'श्रीमती सुप्रिया सदानंद सुले', 'श्री रामविलास पासवान', 'श्रीमती सुप्रिया सदानंद सुले', 'माननीय सभापति', 'SHRIMATI SUPRIYA SULE', 'SHRI KIREN RIJIJU', 'SHRIMATI SUPRIYA SADANAND SULE', 'HON. CHAIRPERSON', 'SHRIMATI SUPRIYA SADANAND SULE', 'HON. CHAIRPERSON', 'SHRIMATI SUPRIYA SADANAND SULE', 'HON. CHAIRPERSON', 'SHRIMATI SUPRIYA SADANAND SULE', 'माननीय सभापति', None, 'माननीय सभापति', 'श्री चिराग कुमार पासवान', 'श्रीमती अनुप्रिया पटेल ', 'श्री खगेन मुर्मु ', 'श्री एम . बदरुद्दीन अजमल ', 'HON . CHAIRPERSON', 'श्री एम . बदरुद्दीन अजमल', 'SHRI P. RAVEENDRANATH KUMAR ', 'HON . CHAIRPERSON', 'SHRI P. RAVEENDRANATH KUMAR', 'माननीय सभापति', 'HON. CHAIRPERSON', 'माननीय सभापति', 'माननीय सभापति', 'SHRI THOMAS CHAZHIKADAN ', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'HON. CHAIRPERSON', 'SHRI PRALHAD JOSHI', 'HON. CHAIRPERSON', None, None, 'SHRI TEJASVI SURYA ', 'SHRIMATI KANIMOZHI KARUNANIDHI', 'SHRI TEJASVI SURYA', 'HON. CHAIRPERSON', 'SHRI TEJASVI SURYA', 'SHRI B. MANICKAM TAGORE ', 'SHRI TEJASVI SURYA', 'HON. CHAIRPERSON', 'SHRI TEJASVI SURYA', 'HON. CHAIRPERSON', 'SHRI TEJASVI SURYA', 'HON. CHAIRPERSON', 'SHRI TEJASVI SURYA', 'SHRI K. SUDHAKARAN ', 'श्रीमती संगीता आजाद ', 'माननीय अध्यक्ष', 'माननीय अध्यक्ष', None, 'माननीय अध्यक्ष', 'श्री जुगल किशोर शर्मा ', 'SHRI KOTHA PRABHAKAR REDDY ', 'श्री अकबर लोन ', 'SHRI TEJASVI SUR ...

# %%
# Remove the first word, the title/honorofic
# Remove any puntunation in between the name
# Trim Extra Spaces
# Remove and zero width characters like \u200b etc.

def name_normalization_one(name: str)->str:
    if pd.isna(name):
        return name
    name = re.sub(r'[\u200b\u200c\u200d]', '', name)
    name = re.sub(r'\(.*?\)', '', name)
    name = re.sub(r'^\S+\s*', '', name)
    name = re.sub(r'[.\-]', '', name)
    name = name.strip()
    return name

df["Speaker"] = df["Speaker"].astype(str).apply(name_normalization_one)
display(df)
# Out:
#                     Speaker  \
# 0
# 1    ADHIR RANJAN CHOWDHURY
# 2    ADHIR RANJAN CHOWDHURY
# 3         KODIKUNNIL SURESH
# 4    ADHIR RANJAN CHOWDHURY
# ..                      ...
# 191                 अध्यक्ष
# 192
# 193               DK SURESH
# 194  राजेश नारणभाई चुड़ासमा
# 195                 अध्यक्ष
#
#                                                 Speech  Words_in_Speech  \
# 0    Title: Further discussion on Motion of Thanks ...               28
# 1    Hon. Speaker Sir, I rise to dwell on the Presi...              231
# 2    I have not referred to anybody’s name. …(Inter...                8
# 3    You can say anything in the House. …(Interrupt...               48
# 4    Sir, I have not said any unparliamentary word....               22
# ..                                                 ...              ...
# 191  आपकी लिस्ट पूरी हो गई । एडवोकेट अजय भट्ट: मान्...             7335
# 192  सीधी मैं महामहिम राष्ट्रपति जी के अभिभाषण पर ध...             6137
# 193  I would like to express my views on motion of ...              698
# 194  महामहिम राष्ट्रपति जी के द्वारा संसद में दिए ग...              845
# 195  सभा की कार्यवाही गुरुवार, दिनांक 6 फरवरी, 2020...              281
#
#     Language
# 0         en
# 1         hi
# 2         en
# 3         en
# 4         en
# ..       ...
# 191       hi
# 192       hi
# 193       en
# 194       hi
# 195       hi
#
# [196 rows x 4 columns]

# %%
df = df[~((df['Words_in_Speech'] < 50) | (df['Speaker'].isna()) | (df['Speaker'].str.strip() == ''))]
df = df.reset_index(drop=True)

pd.set_option('display.max_rows', None)
display(df)
# Out:
#                    Speaker                                             Speech  \
# 0   ADHIR RANJAN CHOWDHURY  Hon. Speaker Sir, I rise to dwell on the Presi...
# 1          अधीर रंजन चौधरी  सर , अगर आपको यह लगे कि मैंने कोई अनपार्लियामे...
# 2                  अध्यक्ष  सभी सदस्य अपनी राय रख सकते हैं , यह सदन सबका ह...
# 3          अधीर रंजन चौधरी  सर , आप रूलिंग दे सकते हैं , पर मेरे कहने का म...
# 4          अधीर रंजन चौधरी  हाँ ,हाँ,तुम्हें ज्यादा मालूम है ।…(व्यवधान) स...
# 5          अधीर रंजन चौधरी  विवेकानन्द जी ने यह भी कहा था कि “ every soul ...
# 6          अधीर रंजन चौधरी  जी सर , सबके प्रधान मंत्री है । मैं प्रधान मंत...
# 7          अधीर रंजन चौधरी  सर , आज हालात यह हो गए हैं कि New Delhi is now...
# 8          अधीर रंजन चौधरी  सर ,यह जो सरकार आई,यह चेस्ट थम्पिंग गवर्नमेंट ...
# 9          अधीर रंजन चौधरी  सर , सेकण्ड रिपब्लिक का मतलब क्या होता है ? से...
# 10                 अध्यक्ष  आप बोलिए । …( व्यवधान ) * * श्री जसवंतसिंह सुम...
# 11             पी पी चौधरी  अध्यक्ष महोदय ,राष्ट्रपति जी के अभिभाषण पर चर्...
# 12             CHAIRPERSON  Please address the Chair. No cross talk. Pleas...
# 13      BHARTRUHARI MAHTAB  What was Oxfam doing there? PROF. SOUGATA RAY:...
# 14             CHAIRPERSON  We will check the record. … (Interruptions) TH...
# 15        हरसिमरत कौर बादल  आम आदमी पार्टी के लोग फायरिंग कर रहे हैं ।…(व्...
# 16      BHARTRUHARI MAHTAB  Hon. Chairperson, if I heard correctly, did he...
# 17      BHARTRUHARI MAHTAB  They are more in Dum Dum area. PROF. SOUGATA R...
# 18             CHAIRPERSON  You are having only one minute. Do not unneces...
# 19             CHAIRPERSON  Please take your seat. Prof. Ray, you address ...
# 20             CHAIRPERSON  I already called Mr. Jayadev’s name. please co...
# 21           JAYADEV GALLA  Sir, thank you for giving me this opportunity ...
# 22           JAYADEV GALLA  Among the many challenges we are facing, the m...
# 23           JAYADEV GALLA  The bifurcation of Andhra Pradesh was done thr...
# 24           JAYADEV GALLA  Sir, the current CM in the Assembly in 2014 ha...
# 25           JAYADEV GALLA  Before the reports were released,…*made statem...
# 26             CHAIRPERSON  Hon. Member, please take your seat. Mr. Jayade...
# 27           JAYADEV GALLA  Now, I come to the point of legal, moral and e...
# 28           JAYADEV GALLA  Sir, 29,000 farmers have donated 34,000 acres ...
# 29           JAYADEV GALLA  Sir, I would like to say just two things befor...
# 30          हनुमान बेनीवाल  सभापति जी , आपने मुझे महामहिम राष्ट्रपति जी के...
# 31          हनुमान बेनीवाल  सभापति महोदय , मैं वहां का सांसद हूं , मैं वोट...
# 32          हनुमान बेनीवाल  सभापति महोदय , एक मिनट में अपनी बात समाप्त करू...
# 33          हनुमान बेनीवाल  सभापति महोदय , रोजगार के बारे में सरकार को सोच...
# 34             CHAIRPERSON  Kindly conclude please. PROF. ACHYUTANANDA SAM...
# 35        SRIDHAR KOTAGIRI  It is an honour to get this opportunity to add...
# 36        SRIDHAR KOTAGIRI  All right, Sir,…*even boasted on live TV of be...
# 37        SRIDHAR KOTAGIRI  Sir, I am concluding it in one minute. We hear...
# 38        SRIDHAR KOTAGIRI  It reduces travel time by two hours from Visak...
# 39   SUPRIYA SADANAND SULE  I come from Maharashtra where you are not in p...
# 40   SUPRIYA SADANAND SULE  That is okay. It does not matter. She was very...
# 41         रामविलास पासवान  हम लोग उसके बारे में सोच रहे हैं । अभी तक बाजा...
# 42    सुप्रिया सदानंद सुले  लेकिन आप प्याज के लिए क्या करेंगे , क्योंकि आज...
# 43         रामविलास पासवान  आपकी जो भावना है , मैं उससे सहमत हूं । सबसे बड़...
# 44            SUPRIYA SULE  He was intervening. It was very kind of the Mi...
# 45   SUPRIYA SADANAND SULE  I am just highlighting it. I am talking about ...
# 46   SUPRIYA SADANAND SULE  Sir, this is my last point. This is very impor...
# 47      चिराग कुमार पासवान  जब एनआरसी आएगा ,तो उस वक्त आप इन बातों को उठाइ...
# 48          अनुप्रिया पटेल  महोदय , धन्यवाद । 17.04 hrs ( Shri Kodikunnil ...
# 49             खगेन मुर्मु  माननीय सभापति जी , आपको बहुत - बहुत धन्यवाद कि...
# 50      एम  बदरुद्दीन अजमल  माननीय सभापति महोदय , सबसे पहले मैं आपका धन्यव...
# 51      एम  बदरुद्दीन अजमल  माननीय सभापति महोदय , मजहब नहीं सिखाता आपस में...
# 52   P RAVEENDRANATH KUMAR  Sir, I wish to thank you for giving me this op...
# 53   P RAVEENDRANATH KUMAR  I am just concluding. I am very proud to say t...
# 54             CHAIRPERSON  No, your time is over. सुश्री प्रतिमा भौमिक : ...
# 55                  सभापति  मैडम , मैंने आपको ज्यादा टाइम दे दिया , so ple...
# 56                  सभापति  मैडम , क्या यह आपकी मेडन स्पीच है ? सुश्री प्र...
# 57      THOMAS CHAZHIKADAN  Hon. Chairperson Sir, thank you very much for ...
# 58             CHAIRPERSON  Hon. Members, it is 6 o’clock now. I have a li...
# 59           TEJASVI SURYA  Thank you, Chairman, Sir, for this opportunity...
# 60           TEJASVI SURYA  Every single day, you have been engaging in a ...
# 61           TEJASVI SURYA  Sir, Varsha, a 12-year-old Hindu girl was abdu...
# 62           TEJASVI SURYA  Kanimozhi Ji, I want to draw your attention to...
# 63           TEJASVI SURYA  But, today, from Indira Awas Yojana to Pradhan...
# 64            K SUDHAKARAN  Thank you, Sir. Once upon a time, there was an...
# 65             संगीता आजाद  सभापति महोदय , आपने मुझे महामहिम राष्ट्रपति मह...
# 66        जुगल किशोर शर्मा  आदरणीय अध्यक्ष महोदय , मैं आपका आभार प्रकट करन...
# 67   KOTHA PRABHAKAR REDDY  At the outset, I am delighted to inform the Ho...
# 68                अकबर लोन  ऑनरेबल स्पीकर साहब , देर से ही सही टाइम तो मिल...
# 69              AKBAR LONE  I know you. Sit down. Do not talk unnecessaril...
# 70              AKBAR LONE  I withdraw. खुश हो गए ! इसी प्रकार मैं टूरिज्म...
# 71                 अध्यक्ष  माननीय सदस्य, यह एनसीआर का विरोध है या एनआरसी ...
# 72      DNV SENTHILKUMAR S  Vanakkam, Speaker Sir! Thank you for giving me...
# 73              राजू बिष्ट  महोदय, मैं सबसे पहले महामहिम राष्ट्रपति जी के ...
# 74                 अध्यक्ष  आपकी लिस्ट पूरी हो गई । एडवोकेट अजय भट्ट: मान्...
# 75               DK SURESH  I would like to express my views on motion of ...
# 76  राजेश नारणभाई चुड़ासमा  महामहिम राष्ट्रपति जी के द्वारा संसद में दिए ग...
# 77                 अध्यक्ष  सभा की कार्यवाही गुरुवार, दिनांक 6 फरवरी, 2020...
#
#     Words_in_Speech Language
# 0               231       hi
# 1               109       hi
# 2                63       hi
# 3                52       hi
# 4               268       hi
# 5              3578       hi
# 6               875       hi
# 7               662       hi
# 8               270       hi
# 9               649       hi
# 10             6180       hi
# 11             5421       hi
# 12              605       hi
# 13              151       hi
# 14              279       en
# 15              738       hi
# 16               56       en
# 17              269       en
# 18              115       en
# 19              404       hi
# 20               57       en
# 21              329       en
# 22              402       en
# 23              249       en
# 24               88       en
# 25              181       en
# 26               57       en
# 27               82       en
# 28               66       en
# 29              121       en
# 30             1588       hi
# 31              366       hi
# 32              166       hi
# 33               95       hi
# 34              373       en
# 35              162       en
# 36             1031       en
# 37              109       en
# 38              639       hi
# 39              218       hi
# 40              185       hi
# 41              186       hi
# 42               58       hi
# 43              173       hi
# 44              114       en
# 45              357       hi
# 46               89       en
# 47             1742       hi
# 48             1337       hi
# 49             2077       hi
# 50              227       hi
# 51             5217       hi
# 52              661       en
# 53             1648       hi
# 54              274       hi
# 55               72       hi
# 56               77       hi
# 57             1012       en
# 58               65       en
# 59              742       en
# 60              101       en
# 61              646       en
# 62              143       en
# 63              232       en
# 64             1534       en
# 65             1016       hi
# 66             1237       hi
# 67              391       en
# 68              171       hi
# 69              489       hi
# 70              924       hi
# 71              667       hi
# 72              475       en
# 73             1563       hi
# 74             7335       hi
# 75              698       en
# 76              845       hi
# 77              281       hi

# %%
# %pip install indic_transliteration

# %%
# from indic_transliteration import sanscript
# from indic_transliteration.sanscript import transliterate
# import pandas as pd
# import re

# def transliterate_if_hindi(name, lang):
#     # If name is missing or not a string, skip
#     if pd.isna(name) or not isinstance(name, str):
#         return name

#     # Transliterate only if it's Hindi
#     if str(lang).lower() == 'hi':
#         try:
#             return transliterate(name, sanscript.DEVANAGARI, sanscript.ITRANS)
#         except Exception:
#             return name  # fallback if transliteration fails
#     else:
#         return name

# # Apply it to the DataFrame
# df['Speaker'] = df.apply(lambda x: transliterate_if_hindi(x['Speaker'], x['Language']), axis=1)

# # Check result
# display(df)
# Out:
#                           Speaker  \
# 0          ADHIR RANJAN CHOWDHURY
# 1        adhIra raMjana chaudharI
# 2                       adhyakSha
# 3        adhIra raMjana chaudharI
# 4        adhIra raMjana chaudharI
# 5        adhIra raMjana chaudharI
# 6        adhIra raMjana chaudharI
# 7        adhIra raMjana chaudharI
# 8        adhIra raMjana chaudharI
# 9        adhIra raMjana chaudharI
# 10                      adhyakSha
# 11                pI pI chaudharI
# 12                    CHAIRPERSON
# 13             BHARTRUHARI MAHTAB
# 14                    CHAIRPERSON
# 15      harasimarata kaura bAdala
# 16             BHARTRUHARI MAHTAB
# 17             BHARTRUHARI MAHTAB
# 18                    CHAIRPERSON
# 19                    CHAIRPERSON
# 20                    CHAIRPERSON
# 21                  JAYADEV GALLA
# 22                  JAYADEV GALLA
# 23                  JAYADEV GALLA
# 24                  JAYADEV GALLA
# 25                  JAYADEV GALLA
# 26                    CHAIRPERSON
# 27                  JAYADEV GALLA
# 28                  JAYADEV GALLA
# 29                  JAYADEV GALLA
# 30              hanumAna benIvAla
# 31              hanumAna benIvAla
# 32              hanumAna benIvAla
# 33              hanumAna benIvAla
# 34                    CHAIRPERSON
# 35               SRIDHAR KOTAGIRI
# 36               SRIDHAR KOTAGIRI
# 37               SRIDHAR KOTAGIRI
# 38               SRIDHAR KOTAGIRI
# 39          SUPRIYA SADANAND SULE
# 40          SUPRIYA SADANAND SULE
# 41            rAmavilAsa pAsavAna
# 42         supriyA sadAnaMda sule
# 43            rAmavilAsa pAsavAna
# 44                   SUPRIYA SULE
# 45          SUPRIYA SADANAND SULE
# 46          SUPRIYA SADANAND SULE
# 47        chirAga kumAra pAsavAna
# 48                anupriyA paTela
# 49                  khagena murmu
# 50       ema  badaruddIna ajamala
# 51       ema  badaruddIna ajamala
# 52          P RAVEENDRANATH KUMAR
# 53          P RAVEENDRANATH KUMAR
# 54                    CHAIRPERSON
# 55                      sabhApati
# 56                      sabhApati
# 57             THOMAS CHAZHIKADAN
# 58                    CHAIRPERSON
# 59                  TEJASVI SURYA
# 60                  TEJASVI SURYA
# 61                  TEJASVI SURYA
# 62                  TEJASVI SURYA
# 63                  TEJASVI SURYA
# 64                   K SUDHAKARAN
# 65                  saMgItA AjAda
# 66          jugala kishora sharmA
# 67          KOTHA PRABHAKAR REDDY
# 68                   akabara lona
# 69                     AKBAR LONE
# 70                     AKBAR LONE
# 71                      adhyakSha
# 72             DNV SENTHILKUMAR S
# 73                    rAjU biShTa
# 74                      adhyakSha
# 75                      DK SURESH
# 76  rAjesha nAraNabhAI chu.DAsamA
# 77                      adhyakSha
#
#                                                Speech  Words_in_Speech  \
# 0   Hon. Speaker Sir, I rise to dwell on the Presi...              231
# 1   सर , अगर आपको यह लगे कि मैंने कोई अनपार्लियामे...              109
# 2   सभी सदस्य अपनी राय रख सकते हैं , यह सदन सबका ह...               63
# 3   सर , आप रूलिंग दे सकते हैं , पर मेरे कहने का म...               52
# 4   हाँ ,हाँ,तुम्हें ज्यादा मालूम है ।…(व्यवधान) स...              268
# 5   विवेकानन्द जी ने यह भी कहा था कि “ every soul ...             3578
# 6   जी सर , सबके प्रधान मंत्री है । मैं प्रधान मंत...              875
# 7   सर , आज हालात यह हो गए हैं कि New Delhi is now...              662
# 8   सर ,यह जो सरकार आई,यह चेस्ट थम्पिंग गवर्नमेंट ...              270
# 9   सर , सेकण्ड रिपब्लिक का मतलब क्या होता है ? से...              649
# 10  आप बोलिए । …( व्यवधान ) * * श्री जसवंतसिंह सुम...             6180
# 11  अध्यक्ष महोदय ,राष्ट्रपति जी के अभिभाषण पर चर्...             5421
# 12  Please address the Chair. No cross talk. Pleas...              605
# 13  What was Oxfam doing there? PROF. SOUGATA RAY:...              151
# 14  We will check the record. … (Interruptions) TH...              279
# 15  आम आदमी पार्टी के लोग फायरिंग कर रहे हैं ।…(व्...              738
# 16  Hon. Chairperson, if I heard correctly, did he...               56
# 17  They are more in Dum Dum area. PROF. SOUGATA R...              269
# 18  You are having only one minute. Do not unneces...              115
# 19  Please take your seat. Prof. Ray, you address ...              404
# 20  I already called Mr. Jayadev’s name. please co...               57
# 21  Sir, thank you for giving me this opportunity ...              329
# 22  Among the many challenges we are facing, the m...              402
# 23  The bifurcation of Andhra Pradesh was done thr...              249
# 24  Sir, the current CM in the Assembly in 2014 ha...               88
# 25  Before the reports were released,…*made statem...              181
# 26  Hon. Member, please take your seat. Mr. Jayade...               57
# 27  Now, I come to the point of legal, moral and e...               82
# 28  Sir, 29,000 farmers have donated 34,000 acres ...               66
# 29  Sir, I would like to say just two things befor...              121
# 30  सभापति जी , आपने मुझे महामहिम राष्ट्रपति जी के...             1588
# 31  सभापति महोदय , मैं वहां का सांसद हूं , मैं वोट...              366
# 32  सभापति महोदय , एक मिनट में अपनी बात समाप्त करू...              166
# 33  सभापति महोदय , रोजगार के बारे में सरकार को सोच...               95
# 34  Kindly conclude please. PROF. ACHYUTANANDA SAM...              373
# 35  It is an honour to get this opportunity to add...              162
# 36  All right, Sir,…*even boasted on live TV of be...             1031
# 37  Sir, I am concluding it in one minute. We hear...              109
# 38  It reduces travel time by two hours from Visak...              639
# 39  I come from Maharashtra where you are not in p...              218
# 40  That is okay. It does not matter. She was very...              185
# 41  हम लोग उसके बारे में सोच रहे हैं । अभी तक बाजा...              186
# 42  लेकिन आप प्याज के लिए क्या करेंगे , क्योंकि आज...               58
# 43  आपकी जो भावना है , मैं उससे सहमत हूं । सबसे बड़...              173
# 44  He was intervening. It was very kind of the Mi...              114
# 45  I am just highlighting it. I am talking about ...              357
# 46  Sir, this is my last point. This is very impor...               89
# 47  जब एनआरसी आएगा ,तो उस वक्त आप इन बातों को उठाइ...             1742
# 48  महोदय , धन्यवाद । 17.04 hrs ( Shri Kodikunnil ...             1337
# 49  माननीय सभापति जी , आपको बहुत - बहुत धन्यवाद कि...             2077
# 50  माननीय सभापति महोदय , सबसे पहले मैं आपका धन्यव...              227
# 51  माननीय सभापति महोदय , मजहब नहीं सिखाता आपस में...             5217
# 52  Sir, I wish to thank you for giving me this op...              661
# 53  I am just concluding. I am very proud to say t...             1648
# 54  No, your time is over. सुश्री प्रतिमा भौमिक : ...              274
# 55  मैडम , मैंने आपको ज्यादा टाइम दे दिया , so ple...               72
# 56  मैडम , क्या यह आपकी मेडन स्पीच है ? सुश्री प्र...               77
# 57  Hon. Chairperson Sir, thank you very much for ...             1012
# 58  Hon. Members, it is 6 o’clock now. I have a li...               65
# 59  Thank you, Chairman, Sir, for this opportunity...              742
# 60  Every single day, you have been engaging in a ...              101
# 61  Sir, Varsha, a 12-year-old Hindu girl was abdu...              646
# 62  Kanimozhi Ji, I want to draw your attention to...              143
# 63  But, today, from Indira Awas Yojana to Pradhan...              232
# 64  Thank you, Sir. Once upon a time, there was an...             1534
# 65  सभापति महोदय , आपने मुझे महामहिम राष्ट्रपति मह...             1016
# 66  आदरणीय अध्यक्ष महोदय , मैं आपका आभार प्रकट करन...             1237
# 67  At the outset, I am delighted to inform the Ho...              391
# 68  ऑनरेबल स्पीकर साहब , देर से ही सही टाइम तो मिल...              171
# 69  I know you. Sit down. Do not talk unnecessaril...              489
# 70  I withdraw. खुश हो गए ! इसी प्रकार मैं टूरिज्म...              924
# 71  माननीय सदस्य, यह एनसीआर का विरोध है या एनआरसी ...              667
# 72  Vanakkam, Speaker Sir! Thank you for giving me...              475
# 73  महोदय, मैं सबसे पहले महामहिम राष्ट्रपति जी के ...             1563
# 74  आपकी लिस्ट पूरी हो गई । एडवोकेट अजय भट्ट: मान्...             7335
# 75  I would like to express my views on motion of ...              698
# 76  महामहिम राष्ट्रपति जी के द्वारा संसद में दिए ग...              845
# 77  सभा की कार्यवाही गुरुवार, दिनांक 6 फरवरी, 2020...              281
#
#    Language
# 0        hi
# 1        hi
# 2        hi
# 3        hi
# 4        hi
# 5        hi
# 6        hi
# 7        hi
# 8        hi
# 9        hi
# 10       hi
# 11       hi
# 12       hi
# 13       hi
# 14       en
# 15       hi
# 16       en
# 17       en
# 18       en
# 19       hi
# 20       en
# 21       en
# 22       en
# 23       en
# 24       en
# 25       en
# 26       en
# 27       en
# 28       en
# 29       en
# 30       hi
# 31       hi
# 32       hi
# 33       hi
# 34       en
# 35       en
# 36       en
# 37       en
# 38       hi
# 39       hi
# 40       hi
# 41       hi
# 42       hi
# 43       hi
# 44       en
# 45       hi
# 46       en
# 47       hi
# 48       hi
# 49       hi
# 50       hi
# 51       hi
# 52       en
# 53       hi
# 54       hi
# 55       hi
# 56       hi
# 57       en
# 58       en
# 59       en
# 60       en
# 61       en
# 62       en
# 63       en
# 64       en
# 65       hi
# 66       hi
# 67       en
# 68       hi
# 69       hi
# 70       hi
# 71       hi
# 72       en
# 73       hi
# 74       hi
# 75       en
# 76       hi
# 77       hi

# %%
import pandas as pd
import re
from aksharamukha import transliterate

# detect if text contains Devanagari characters
DEVANAGARI_RE = re.compile(r'[\u0900-\u097F]')

def transliterate_if_hindi(name, lang):
    if pd.isna(name) or not isinstance(name, str) or name.strip() == '':
        return name

    lang_str = '' if pd.isna(lang) else str(lang).strip().lower()
    is_hindi = (lang_str in ('hi', 'hindi')) or bool(DEVANAGARI_RE.search(name))

    if not is_hindi:
        return name

    try:
        # Convert from Devanagari → Latin (ISO) and make uppercase
        transliterated = transliterate.process('Devanagari', 'ISO', name)
        return transliterated.upper()
    except Exception:
        return name  # fallback if transliteration fails

# Apply to your dataframe
df['Speaker'] = df.apply(lambda row: transliterate_if_hindi(row['Speaker'], row.get('Language')), axis=1)

# See result
display(df)
# Out:
#                           Speaker  \
# 0          ADHIR RANJAN CHOWDHURY
# 1        ADHIRA RAMJANA CHAUDHARI
# 2                       ADHYAKSHA
# 3        ADHIRA RAMJANA CHAUDHARI
# 4        ADHIRA RAMJANA CHAUDHARI
# 5        ADHIRA RAMJANA CHAUDHARI
# 6        ADHIRA RAMJANA CHAUDHARI
# 7        ADHIRA RAMJANA CHAUDHARI
# 8        ADHIRA RAMJANA CHAUDHARI
# 9        ADHIRA RAMJANA CHAUDHARI
# 10                      ADHYAKSHA
# 11                PI PI CHAUDHARI
# 12                    CHAIRPERSON
# 13             BHARTRUHARI MAHTAB
# 14                    CHAIRPERSON
# 15      HARASIMARATA KAURA BADALA
# 16             BHARTRUHARI MAHTAB
# 17             BHARTRUHARI MAHTAB
# 18                    CHAIRPERSON
# 19                    CHAIRPERSON
# 20                    CHAIRPERSON
# 21                  JAYADEV GALLA
# 22                  JAYADEV GALLA
# 23                  JAYADEV GALLA
# 24                  JAYADEV GALLA
# 25                  JAYADEV GALLA
# 26                    CHAIRPERSON
# 27                  JAYADEV GALLA
# 28                  JAYADEV GALLA
# 29                  JAYADEV GALLA
# 30              HANUMANA BENIVALA
# 31              HANUMANA BENIVALA
# 32              HANUMANA BENIVALA
# 33              HANUMANA BENIVALA
# 34                    CHAIRPERSON
# 35               SRIDHAR KOTAGIRI
# 36               SRIDHAR KOTAGIRI
# 37               SRIDHAR KOTAGIRI
# 38               SRIDHAR KOTAGIRI
# 39          SUPRIYA SADANAND SULE
# 40          SUPRIYA SADANAND SULE
# 41            RAMAVILASA PASAVANA
# 42         SUPRIYA SADANAMDA SULE
# 43            RAMAVILASA PASAVANA
# 44                   SUPRIYA SULE
# 45          SUPRIYA SADANAND SULE
# 46          SUPRIYA SADANAND SULE
# 47        CHIRAGA KUMARA PASAVANA
# 48                ANUPRIYA PATELA
# 49                  KHAGENA MURMU
# 50       EMA  BADARUDDINA AJAMALA
# 51       EMA  BADARUDDINA AJAMALA
# 52          P RAVEENDRANATH KUMAR
# 53          P RAVEENDRANATH KUMAR
# 54                    CHAIRPERSON
# 55                      SABHAPATI
# 56                      SABHAPATI
# 57             THOMAS CHAZHIKADAN
# 58                    CHAIRPERSON
# 59                  TEJASVI SURYA
# 60                  TEJASVI SURYA
# 61                  TEJASVI SURYA
# 62                  TEJASVI SURYA
# 63                  TEJASVI SURYA
# 64                   K SUDHAKARAN
# 65                  SAMGITA AJADA
# 66          JUGALA KISHORA SHARMA
# 67          KOTHA PRABHAKAR REDDY
# 68                   AKABARA LONA
# 69                     AKBAR LONE
# 70                     AKBAR LONE
# 71                      ADHYAKSHA
# 72             DNV SENTHILKUMAR S
# 73                    RAJU BISHTA
# 74                      ADHYAKSHA
# 75                      DK SURESH
# 76  RAJESHA NARANABHAI CHU.DASAMA
# 77                      ADHYAKSHA
#
#                                                Speech  Words_in_Speech  \
# 0   Hon. Speaker Sir, I rise to dwell on the Presi...              231
# 1   सर , अगर आपको यह लगे कि मैंने कोई अनपार्लियामे...              109
# 2   सभी सदस्य अपनी राय रख सकते हैं , यह सदन सबका ह...               63
# 3   सर , आप रूलिंग दे सकते हैं , पर मेरे कहने का म...               52
# 4   हाँ ,हाँ,तुम्हें ज्यादा मालूम है ।…(व्यवधान) स...              268
# 5   विवेकानन्द जी ने यह भी कहा था कि “ every soul ...             3578
# 6   जी सर , सबके प्रधान मंत्री है । मैं प्रधान मंत...              875
# 7   सर , आज हालात यह हो गए हैं कि New Delhi is now...              662
# 8   सर ,यह जो सरकार आई,यह चेस्ट थम्पिंग गवर्नमेंट ...              270
# 9   सर , सेकण्ड रिपब्लिक का मतलब क्या होता है ? से...              649
# 10  आप बोलिए । …( व्यवधान ) * * श्री जसवंतसिंह सुम...             6180
# 11  अध्यक्ष महोदय ,राष्ट्रपति जी के अभिभाषण पर चर्...             5421
# 12  Please address the Chair. No cross talk. Pleas...              605
# 13  What was Oxfam doing there? PROF. SOUGATA RAY:...              151
# 14  We will check the record. … (Interruptions) TH...              279
# 15  आम आदमी पार्टी के लोग फायरिंग कर रहे हैं ।…(व्...              738
# 16  Hon. Chairperson, if I heard correctly, did he...               56
# 17  They are more in Dum Dum area. PROF. SOUGATA R...              269
# 18  You are having only one minute. Do not unneces...              115
# 19  Please take your seat. Prof. Ray, you address ...              404
# 20  I already called Mr. Jayadev’s name. please co...               57
# 21  Sir, thank you for giving me this opportunity ...              329
# 22  Among the many challenges we are facing, the m...              402
# 23  The bifurcation of Andhra Pradesh was done thr...              249
# 24  Sir, the current CM in the Assembly in 2014 ha...               88
# 25  Before the reports were released,…*made statem...              181
# 26  Hon. Member, please take your seat. Mr. Jayade...               57
# 27  Now, I come to the point of legal, moral and e...               82
# 28  Sir, 29,000 farmers have donated 34,000 acres ...               66
# 29  Sir, I would like to say just two things befor...              121
# 30  सभापति जी , आपने मुझे महामहिम राष्ट्रपति जी के...             1588
# 31  सभापति महोदय , मैं वहां का सांसद हूं , मैं वोट...              366
# 32  सभापति महोदय , एक मिनट में अपनी बात समाप्त करू...              166
# 33  सभापति महोदय , रोजगार के बारे में सरकार को सोच...               95
# 34  Kindly conclude please. PROF. ACHYUTANANDA SAM...              373
# 35  It is an honour to get this opportunity to add...              162
# 36  All right, Sir,…*even boasted on live TV of be...             1031
# 37  Sir, I am concluding it in one minute. We hear...              109
# 38  It reduces travel time by two hours from Visak...              639
# 39  I come from Maharashtra where you are not in p...              218
# 40  That is okay. It does not matter. She was very...              185
# 41  हम लोग उसके बारे में सोच रहे हैं । अभी तक बाजा...              186
# 42  लेकिन आप प्याज के लिए क्या करेंगे , क्योंकि आज...               58
# 43  आपकी जो भावना है , मैं उससे सहमत हूं । सबसे बड़...              173
# 44  He was intervening. It was very kind of the Mi...              114
# 45  I am just highlighting it. I am talking about ...              357
# 46  Sir, this is my last point. This is very impor...               89
# 47  जब एनआरसी आएगा ,तो उस वक्त आप इन बातों को उठाइ...             1742
# 48  महोदय , धन्यवाद । 17.04 hrs ( Shri Kodikunnil ...             1337
# 49  माननीय सभापति जी , आपको बहुत - बहुत धन्यवाद कि...             2077
# 50  माननीय सभापति महोदय , सबसे पहले मैं आपका धन्यव...              227
# 51  माननीय सभापति महोदय , मजहब नहीं सिखाता आपस में...             5217
# 52  Sir, I wish to thank you for giving me this op...              661
# 53  I am just concluding. I am very proud to say t...             1648
# 54  No, your time is over. सुश्री प्रतिमा भौमिक : ...              274
# 55  मैडम , मैंने आपको ज्यादा टाइम दे दिया , so ple...               72
# 56  मैडम , क्या यह आपकी मेडन स्पीच है ? सुश्री प्र...               77
# 57  Hon. Chairperson Sir, thank you very much for ...             1012
# 58  Hon. Members, it is 6 o’clock now. I have a li...               65
# 59  Thank you, Chairman, Sir, for this opportunity...              742
# 60  Every single day, you have been engaging in a ...              101
# 61  Sir, Varsha, a 12-year-old Hindu girl was abdu...              646
# 62  Kanimozhi Ji, I want to draw your attention to...              143
# 63  But, today, from Indira Awas Yojana to Pradhan...              232
# 64  Thank you, Sir. Once upon a time, there was an...             1534
# 65  सभापति महोदय , आपने मुझे महामहिम राष्ट्रपति मह...             1016
# 66  आदरणीय अध्यक्ष महोदय , मैं आपका आभार प्रकट करन...             1237
# 67  At the outset, I am delighted to inform the Ho...              391
# 68  ऑनरेबल स्पीकर साहब , देर से ही सही टाइम तो मिल...              171
# 69  I know you. Sit down. Do not talk unnecessaril...              489
# 70  I withdraw. खुश हो गए ! इसी प्रकार मैं टूरिज्म...              924
# 71  माननीय सदस्य, यह एनसीआर का विरोध है या एनआरसी ...              667
# 72  Vanakkam, Speaker Sir! Thank you for giving me...              475
# 73  महोदय, मैं सबसे पहले महामहिम राष्ट्रपति जी के ...             1563
# 74  आपकी लिस्ट पूरी हो गई । एडवोकेट अजय भट्ट: मान्...             7335
# 75  I would like to express my views on motion of ...              698
# 76  महामहिम राष्ट्रपति जी के द्वारा संसद में दिए ग...              845
# 77  सभा की कार्यवाही गुरुवार, दिनांक 6 फरवरी, 2020...              281
#
#    Language
# 0        hi
# 1        hi
# 2        hi
# 3        hi
# 4        hi
# 5        hi
# 6        hi
# 7        hi
# 8        hi
# 9        hi
# 10       hi
# 11       hi
# 12       hi
# 13       hi
# 14       en
# 15       hi
# 16       en
# 17       en
# 18       en
# 19       hi
# 20       en
# 21       en
# 22       en
# 23       en
# 24       en
# 25       en
# 26       en
# 27       en
# 28       en
# 29       en
# 30       hi
# 31       hi
# 32       hi
# 33       hi
# 34       en
# 35       en
# 36       en
# 37       en
# 38       hi
# 39       hi
# 40       hi
# 41       hi
# 42       hi
# 43       hi
# 44       en
# 45       hi
# 46       en
# 47       hi
# 48       hi
# 49       hi
# 50       hi
# 51       hi
# 52       en
# 53       hi
# 54       hi
# 55       hi
# 56       hi
# 57       en
# 58       en
# 59       en
# 60       en
# 61       en
# 62       en
# 63       en
# 64       en
# 65       hi
# 66       hi
# 67       en
# 68       hi
# 69       hi
# 70       hi
# 71       hi
# 72       en
# 73       hi
# 74       hi
# 75       en
# 76       hi
# 77       hi

# %%
# %pip install rapidfuzz
# Out:
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.14.1-cp311-cp311-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 7.6 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz
# Successfully installed rapidfuzz-3.14.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from rapidfuzz import fuzz
from collections import defaultdict

def normalize_name(name):
    return ' '.join(name.upper().split())

def group_names(names, threshold_main=80, threshold_secondary=70):
    names = [normalize_name(n) for n in names]

    # Step 1: Build initial graph based on main threshold
    graph = defaultdict(list)
    for i in range(len(names)):
        for j in range(i + 1, len(names)):
            sim = fuzz.token_set_ratio(names[i], names[j])
            if sim >= threshold_main:
                graph[names[i]].append(names[j])
                graph[names[j]].append(names[i])

    # Step 2: Assign initial groups using connected components
    visited = set()
    id_counter = 1
    groups = {}
    for name in names:
        if name not in visited:
            stack = [name]
            component = []
            while stack:
                current = stack.pop()
                if current not in visited:
                    visited.add(current)
                    component.append(current)
                    for neighbor in graph[current]:
                        if neighbor not in visited:
                            stack.append(neighbor)
            for c in sorted(component):
                groups[c] = id_counter
            id_counter += 1

    # Step 3: Secondary pass for “fuzzy first/last name matches”
    group_items = list(groups.items())
    for i in range(len(group_items)):
        name1, id1 = group_items[i]
        words1 = set(name1.split())
        for j in range(i + 1, len(group_items)):
            name2, id2 = group_items[j]
            if id1 != id2:
                words2 = set(name2.split())
                overlap = len(words1 & words2)
                total = max(len(words1), len(words2))
                partial_ratio = (overlap / total) * 100
                if partial_ratio >= threshold_secondary:
                    # Merge groups
                    old_id, new_id = id2, id1
                    for k in groups:
                        if groups[k] == old_id:
                            groups[k] = new_id

    return groups

final_names=df["Speaker"].unique()
groups = group_names(final_names, threshold_main=70, threshold_secondary=80)
print(groups)
# Out:
# {'ADHIR RANJAN CHOWDHURY': 1, 'ADHIRA RAMJANA CHAUDHARI': 1, 'PI PI CHAUDHARI': 1, 'ADHYAKSHA': 2, 'CHAIRPERSON': 3, 'BHARTRUHARI MAHTAB': 4, 'HARASIMARATA KAURA BADALA': 5, 'JAYADEV GALLA': 6, 'HANUMANA BENIVALA': 7, 'SRIDHAR KOTAGIRI': 8, 'SUPRIYA SADANAMDA SULE': 9, 'SUPRIYA SADANAND SULE': 9, 'SUPRIYA SULE': 9, 'RAMAVILASA PASAVANA': 10, 'CHIRAGA KUMARA PASAVANA': 11, 'ANUPRIYA PATELA': 12, 'KHAGENA MURMU': 13, 'EMA BADARUDDINA AJAMALA': 14, 'P RAVEENDRANATH KUMAR': 15, 'SABHAPATI': 16, 'THOMAS CHAZHIKADAN': 17, 'TEJASVI SURYA': 18, 'K SUDHAKARAN': 19, 'SAMGITA AJADA': 20, 'JUGALA KISHORA SHARMA': 21, 'KOTHA PRABHAKAR REDDY': 22, 'AKABARA LONA': 23, 'AKBAR LONE': 23, 'DNV SENTHILKUMAR S': 24, 'RAJU BISHTA': 25, 'DK SURESH': 26, 'RAJESHA NARANABHAI CHU.DASAMA': 27}

# %%
display(df)
# Out:
#                           Speaker  \
# 0          ADHIR RANJAN CHOWDHURY
# 1        ADHIRA RAMJANA CHAUDHARI
# 2                       ADHYAKSHA
# 3        ADHIRA RAMJANA CHAUDHARI
# 4        ADHIRA RAMJANA CHAUDHARI
# 5        ADHIRA RAMJANA CHAUDHARI
# 6        ADHIRA RAMJANA CHAUDHARI
# 7        ADHIRA RAMJANA CHAUDHARI
# 8        ADHIRA RAMJANA CHAUDHARI
# 9        ADHIRA RAMJANA CHAUDHARI
# 10                      ADHYAKSHA
# 11                PI PI CHAUDHARI
# 12                    CHAIRPERSON
# 13             BHARTRUHARI MAHTAB
# 14                    CHAIRPERSON
# 15      HARASIMARATA KAURA BADALA
# 16             BHARTRUHARI MAHTAB
# 17             BHARTRUHARI MAHTAB
# 18                    CHAIRPERSON
# 19                    CHAIRPERSON
# 20                    CHAIRPERSON
# 21                  JAYADEV GALLA
# 22                  JAYADEV GALLA
# 23                  JAYADEV GALLA
# 24                  JAYADEV GALLA
# 25                  JAYADEV GALLA
# 26                    CHAIRPERSON
# 27                  JAYADEV GALLA
# 28                  JAYADEV GALLA
# 29                  JAYADEV GALLA
# 30              HANUMANA BENIVALA
# 31              HANUMANA BENIVALA
# 32              HANUMANA BENIVALA
# 33              HANUMANA BENIVALA
# 34                    CHAIRPERSON
# 35               SRIDHAR KOTAGIRI
# 36               SRIDHAR KOTAGIRI
# 37               SRIDHAR KOTAGIRI
# 38               SRIDHAR KOTAGIRI
# 39          SUPRIYA SADANAND SULE
# 40          SUPRIYA SADANAND SULE
# 41            RAMAVILASA PASAVANA
# 42         SUPRIYA SADANAMDA SULE
# 43            RAMAVILASA PASAVANA
# 44                   SUPRIYA SULE
# 45          SUPRIYA SADANAND SULE
# 46          SUPRIYA SADANAND SULE
# 47        CHIRAGA KUMARA PASAVANA
# 48                ANUPRIYA PATELA
# 49                  KHAGENA MURMU
# 50       EMA  BADARUDDINA AJAMALA
# 51       EMA  BADARUDDINA AJAMALA
# 52          P RAVEENDRANATH KUMAR
# 53          P RAVEENDRANATH KUMAR
# 54                    CHAIRPERSON
# 55                      SABHAPATI
# 56                      SABHAPATI
# 57             THOMAS CHAZHIKADAN
# 58                    CHAIRPERSON
# 59                  TEJASVI SURYA
# 60                  TEJASVI SURYA
# 61                  TEJASVI SURYA
# 62                  TEJASVI SURYA
# 63                  TEJASVI SURYA
# 64                   K SUDHAKARAN
# 65                  SAMGITA AJADA
# 66          JUGALA KISHORA SHARMA
# 67          KOTHA PRABHAKAR REDDY
# 68                   AKABARA LONA
# 69                     AKBAR LONE
# 70                     AKBAR LONE
# 71                      ADHYAKSHA
# 72             DNV SENTHILKUMAR S
# 73                    RAJU BISHTA
# 74                      ADHYAKSHA
# 75                      DK SURESH
# 76  RAJESHA NARANABHAI CHU.DASAMA
# 77                      ADHYAKSHA
#
#                                                Speech  Words_in_Speech  \
# 0   Hon. Speaker Sir, I rise to dwell on the Presi...              231
# 1   सर , अगर आपको यह लगे कि मैंने कोई अनपार्लियामे...              109
# 2   सभी सदस्य अपनी राय रख सकते हैं , यह सदन सबका ह...               63
# 3   सर , आप रूलिंग दे सकते हैं , पर मेरे कहने का म...               52
# 4   हाँ ,हाँ,तुम्हें ज्यादा मालूम है ।…(व्यवधान) स...              268
# 5   विवेकानन्द जी ने यह भी कहा था कि “ every soul ...             3578
# 6   जी सर , सबके प्रधान मंत्री है । मैं प्रधान मंत...              875
# 7   सर , आज हालात यह हो गए हैं कि New Delhi is now...              662
# 8   सर ,यह जो सरकार आई,यह चेस्ट थम्पिंग गवर्नमेंट ...              270
# 9   सर , सेकण्ड रिपब्लिक का मतलब क्या होता है ? से...              649
# 10  आप बोलिए । …( व्यवधान ) * * श्री जसवंतसिंह सुम...             6180
# 11  अध्यक्ष महोदय ,राष्ट्रपति जी के अभिभाषण पर चर्...             5421
# 12  Please address the Chair. No cross talk. Pleas...              605
# 13  What was Oxfam doing there? PROF. SOUGATA RAY:...              151
# 14  We will check the record. … (Interruptions) TH...              279
# 15  आम आदमी पार्टी के लोग फायरिंग कर रहे हैं ।…(व्...              738
# 16  Hon. Chairperson, if I heard correctly, did he...               56
# 17  They are more in Dum Dum area. PROF. SOUGATA R...              269
# 18  You are having only one minute. Do not unneces...              115
# 19  Please take your seat. Prof. Ray, you address ...              404
# 20  I already called Mr. Jayadev’s name. please co...               57
# 21  Sir, thank you for giving me this opportunity ...              329
# 22  Among the many challenges we are facing, the m...              402
# 23  The bifurcation of Andhra Pradesh was done thr...              249
# 24  Sir, the current CM in the Assembly in 2014 ha...               88
# 25  Before the reports were released,…*made statem...              181
# 26  Hon. Member, please take your seat. Mr. Jayade...               57
# 27  Now, I come to the point of legal, moral and e...               82
# 28  Sir, 29,000 farmers have donated 34,000 acres ...               66
# 29  Sir, I would like to say just two things befor...              121
# 30  सभापति जी , आपने मुझे महामहिम राष्ट्रपति जी के...             1588
# 31  सभापति महोदय , मैं वहां का सांसद हूं , मैं वोट...              366
# 32  सभापति महोदय , एक मिनट में अपनी बात समाप्त करू...              166
# 33  सभापति महोदय , रोजगार के बारे में सरकार को सोच...               95
# 34  Kindly conclude please. PROF. ACHYUTANANDA SAM...              373
# 35  It is an honour to get this opportunity to add...              162
# 36  All right, Sir,…*even boasted on live TV of be...             1031
# 37  Sir, I am concluding it in one minute. We hear...              109
# 38  It reduces travel time by two hours from Visak...              639
# 39  I come from Maharashtra where you are not in p...              218
# 40  That is okay. It does not matter. She was very...              185
# 41  हम लोग उसके बारे में सोच रहे हैं । अभी तक बाजा...              186
# 42  लेकिन आप प्याज के लिए क्या करेंगे , क्योंकि आज...               58
# 43  आपकी जो भावना है , मैं उससे सहमत हूं । सबसे बड़...              173
# 44  He was intervening. It was very kind of the Mi...              114
# 45  I am just highlighting it. I am talking about ...              357
# 46  Sir, this is my last point. This is very impor...               89
# 47  जब एनआरसी आएगा ,तो उस वक्त आप इन बातों को उठाइ...             1742
# 48  महोदय , धन्यवाद । 17.04 hrs ( Shri Kodikunnil ...             1337
# 49  माननीय सभापति जी , आपको बहुत - बहुत धन्यवाद कि...             2077
# 50  माननीय सभापति महोदय , सबसे पहले मैं आपका धन्यव...              227
# 51  माननीय सभापति महोदय , मजहब नहीं सिखाता आपस में...             5217
# 52  Sir, I wish to thank you for giving me this op...              661
# 53  I am just concluding. I am very proud to say t...             1648
# 54  No, your time is over. सुश्री प्रतिमा भौमिक : ...              274
# 55  मैडम , मैंने आपको ज्यादा टाइम दे दिया , so ple...               72
# 56  मैडम , क्या यह आपकी मेडन स्पीच है ? सुश्री प्र...               77
# 57  Hon. Chairperson Sir, thank you very much for ...             1012
# 58  Hon. Members, it is 6 o’clock now. I have a li...               65
# 59  Thank you, Chairman, Sir, for this opportunity...              742
# 60  Every single day, you have been engaging in a ...              101
# 61  Sir, Varsha, a 12-year-old Hindu girl was abdu...              646
# 62  Kanimozhi Ji, I want to draw your attention to...              143
# 63  But, today, from Indira Awas Yojana to Pradhan...              232
# 64  Thank you, Sir. Once upon a time, there was an...             1534
# 65  सभापति महोदय , आपने मुझे महामहिम राष्ट्रपति मह...             1016
# 66  आदरणीय अध्यक्ष महोदय , मैं आपका आभार प्रकट करन...             1237
# 67  At the outset, I am delighted to inform the Ho...              391
# 68  ऑनरेबल स्पीकर साहब , देर से ही सही टाइम तो मिल...              171
# 69  I know you. Sit down. Do not talk unnecessaril...              489
# 70  I withdraw. खुश हो गए ! इसी प्रकार मैं टूरिज्म...              924
# 71  माननीय सदस्य, यह एनसीआर का विरोध है या एनआरसी ...              667
# 72  Vanakkam, Speaker Sir! Thank you for giving me...              475
# 73  महोदय, मैं सबसे पहले महामहिम राष्ट्रपति जी के ...             1563
# 74  आपकी लिस्ट पूरी हो गई । एडवोकेट अजय भट्ट: मान्...             7335
# 75  I would like to express my views on motion of ...              698
# 76  महामहिम राष्ट्रपति जी के द्वारा संसद में दिए ग...              845
# 77  सभा की कार्यवाही गुरुवार, दिनांक 6 फरवरी, 2020...              281
#
#    Language
# 0        hi
# 1        hi
# 2        hi
# 3        hi
# 4        hi
# 5        hi
# 6        hi
# 7        hi
# 8        hi
# 9        hi
# 10       hi
# 11       hi
# 12       hi
# 13       hi
# 14       en
# 15       hi
# 16       en
# 17       en
# 18       en
# 19       hi
# 20       en
# 21       en
# 22       en
# 23       en
# 24       en
# 25       en
# 26       en
# 27       en
# 28       en
# 29       en
# 30       hi
# 31       hi
# 32       hi
# 33       hi
# 34       en
# 35       en
# 36       en
# 37       en
# 38       hi
# 39       hi
# 40       hi
# 41       hi
# 42       hi
# 43       hi
# 44       en
# 45       hi
# 46       en
# 47       hi
# 48       hi
# 49       hi
# 50       hi
# 51       hi
# 52       en
# 53       hi
# 54       hi
# 55       hi
# 56       hi
# 57       en
# 58       en
# 59       en
# 60       en
# 61       en
# 62       en
# 63       en
# 64       en
# 65       hi
# 66       hi
# 67       en
# 68       hi
# 69       hi
# 70       hi
# 71       hi
# 72       en
# 73       hi
# 74       hi
# 75       en
# 76       hi
# 77       hi

# %%
import pandas as pd

# Assuming your DataFrame is df

# Aggregate
agg_df = df.groupby('Speaker').agg({
    'Speech': lambda x: ' <u> '.join(x),      # concatenate speeches
    'Words_in_Speech': 'sum',                # sum words
    'Language': 'first'                      # keep language as it is
}).reset_index()

display(agg_df)
# Out:
#                           Speaker  \
# 0          ADHIR RANJAN CHOWDHURY
# 1        ADHIRA RAMJANA CHAUDHARI
# 2                       ADHYAKSHA
# 3                    AKABARA LONA
# 4                      AKBAR LONE
# 5                 ANUPRIYA PATELA
# 6              BHARTRUHARI MAHTAB
# 7                     CHAIRPERSON
# 8         CHIRAGA KUMARA PASAVANA
# 9                       DK SURESH
# 10             DNV SENTHILKUMAR S
# 11       EMA  BADARUDDINA AJAMALA
# 12              HANUMANA BENIVALA
# 13      HARASIMARATA KAURA BADALA
# 14                  JAYADEV GALLA
# 15          JUGALA KISHORA SHARMA
# 16                   K SUDHAKARAN
# 17                  KHAGENA MURMU
# 18          KOTHA PRABHAKAR REDDY
# 19          P RAVEENDRANATH KUMAR
# 20                PI PI CHAUDHARI
# 21  RAJESHA NARANABHAI CHU.DASAMA
# 22                    RAJU BISHTA
# 23            RAMAVILASA PASAVANA
# 24                      SABHAPATI
# 25                  SAMGITA AJADA
# 26               SRIDHAR KOTAGIRI
# 27         SUPRIYA SADANAMDA SULE
# 28          SUPRIYA SADANAND SULE
# 29                   SUPRIYA SULE
# 30                  TEJASVI SURYA
# 31             THOMAS CHAZHIKADAN
#
#                                                Speech  Words_in_Speech  \
# 0   Hon. Speaker Sir, I rise to dwell on the Presi...              231
# 1   सर , अगर आपको यह लगे कि मैंने कोई अनपार्लियामे...             6463
# 2   सभी सदस्य अपनी राय रख सकते हैं , यह सदन सबका ह...            14526
# 3   ऑनरेबल स्पीकर साहब , देर से ही सही टाइम तो मिल...              171
# 4   I know you. Sit down. Do not talk unnecessaril...             1413
# 5   महोदय , धन्यवाद । 17.04 hrs ( Shri Kodikunnil ...             1337
# 6   What was Oxfam doing there? PROF. SOUGATA RAY:...              476
# 7   Please address the Chair. No cross talk. Pleas...             2229
# 8   जब एनआरसी आएगा ,तो उस वक्त आप इन बातों को उठाइ...             1742
# 9   I would like to express my views on motion of ...              698
# 10  Vanakkam, Speaker Sir! Thank you for giving me...              475
# 11  माननीय सभापति महोदय , सबसे पहले मैं आपका धन्यव...             5444
# 12  सभापति जी , आपने मुझे महामहिम राष्ट्रपति जी के...             2215
# 13  आम आदमी पार्टी के लोग फायरिंग कर रहे हैं ।…(व्...              738
# 14  Sir, thank you for giving me this opportunity ...             1518
# 15  आदरणीय अध्यक्ष महोदय , मैं आपका आभार प्रकट करन...             1237
# 16  Thank you, Sir. Once upon a time, there was an...             1534
# 17  माननीय सभापति जी , आपको बहुत - बहुत धन्यवाद कि...             2077
# 18  At the outset, I am delighted to inform the Ho...              391
# 19  Sir, I wish to thank you for giving me this op...             2309
# 20  अध्यक्ष महोदय ,राष्ट्रपति जी के अभिभाषण पर चर्...             5421
# 21  महामहिम राष्ट्रपति जी के द्वारा संसद में दिए ग...              845
# 22  महोदय, मैं सबसे पहले महामहिम राष्ट्रपति जी के ...             1563
# 23  हम लोग उसके बारे में सोच रहे हैं । अभी तक बाजा...              359
# 24  मैडम , मैंने आपको ज्यादा टाइम दे दिया , so ple...              149
# 25  सभापति महोदय , आपने मुझे महामहिम राष्ट्रपति मह...             1016
# 26  It is an honour to get this opportunity to add...             1941
# 27  लेकिन आप प्याज के लिए क्या करेंगे , क्योंकि आज...               58
# 28  I come from Maharashtra where you are not in p...              849
# 29  He was intervening. It was very kind of the Mi...              114
# 30  Thank you, Chairman, Sir, for this opportunity...             1864
# 31  Hon. Chairperson Sir, thank you very much for ...             1012
#
#    Language
# 0        hi
# 1        hi
# 2        hi
# 3        hi
# 4        hi
# 5        hi
# 6        hi
# 7        hi
# 8        hi
# 9        en
# 10       en
# 11       hi
# 12       hi
# 13       hi
# 14       en
# 15       hi
# 16       en
# 17       hi
# 18       en
# 19       en
# 20       hi
# 21       hi
# 22       hi
# 23       hi
# 24       hi
# 25       hi
# 26       en
# 27       hi
# 28       hi
# 29       en
# 30       en
# 31       en

# %%
import pandas as pd

# Assuming df is your DataFrame and groups is your dictionary
# Step 1: Map each speaker to their group
df['group_id'] = df['Speaker'].map(groups)

# Step 2: Aggregate by group_id
agg_df = df.groupby('group_id').agg({
    'Speaker': lambda x: ' | '.join(sorted(set(x))),   # all speaker variants
    'Speech': lambda x: ' <u> '.join(x),              # all speeches
    'Words_in_Speech': 'sum',                         # total words
    'Language': 'first'                               # assuming same language per group
}).reset_index(drop=True)

# Display the aggregated result
display(agg_df)
# Out:
#                                               Speaker  \
# 0   ADHIR RANJAN CHOWDHURY | ADHIRA RAMJANA CHAUDH...
# 1                                           ADHYAKSHA
# 2                                         CHAIRPERSON
# 3                                  BHARTRUHARI MAHTAB
# 4                           HARASIMARATA KAURA BADALA
# 5                                       JAYADEV GALLA
# 6                                   HANUMANA BENIVALA
# 7                                    SRIDHAR KOTAGIRI
# 8   SUPRIYA SADANAMDA SULE | SUPRIYA SADANAND SULE...
# 9                                 RAMAVILASA PASAVANA
# 10                            CHIRAGA KUMARA PASAVANA
# 11                                    ANUPRIYA PATELA
# 12                                      KHAGENA MURMU
# 13                              P RAVEENDRANATH KUMAR
# 14                                          SABHAPATI
# 15                                 THOMAS CHAZHIKADAN
# 16                                      TEJASVI SURYA
# 17                                       K SUDHAKARAN
# 18                                      SAMGITA AJADA
# 19                              JUGALA KISHORA SHARMA
# 20                              KOTHA PRABHAKAR REDDY
# 21                          AKABARA LONA | AKBAR LONE
# 22                                 DNV SENTHILKUMAR S
# 23                                        RAJU BISHTA
# 24                                          DK SURESH
# 25                      RAJESHA NARANABHAI CHU.DASAMA
#
#                                                Speech  Words_in_Speech  \
# 0   Hon. Speaker Sir, I rise to dwell on the Presi...            12115
# 1   सभी सदस्य अपनी राय रख सकते हैं , यह सदन सबका ह...            14526
# 2   Please address the Chair. No cross talk. Pleas...             2229
# 3   What was Oxfam doing there? PROF. SOUGATA RAY:...              476
# 4   आम आदमी पार्टी के लोग फायरिंग कर रहे हैं ।…(व्...              738
# 5   Sir, thank you for giving me this opportunity ...             1518
# 6   सभापति जी , आपने मुझे महामहिम राष्ट्रपति जी के...             2215
# 7   It is an honour to get this opportunity to add...             1941
# 8   I come from Maharashtra where you are not in p...             1021
# 9   हम लोग उसके बारे में सोच रहे हैं । अभी तक बाजा...              359
# 10  जब एनआरसी आएगा ,तो उस वक्त आप इन बातों को उठाइ...             1742
# 11  महोदय , धन्यवाद । 17.04 hrs ( Shri Kodikunnil ...             1337
# 12  माननीय सभापति जी , आपको बहुत - बहुत धन्यवाद कि...             2077
# 13  Sir, I wish to thank you for giving me this op...             2309
# 14  मैडम , मैंने आपको ज्यादा टाइम दे दिया , so ple...              149
# 15  Hon. Chairperson Sir, thank you very much for ...             1012
# 16  Thank you, Chairman, Sir, for this opportunity...             1864
# 17  Thank you, Sir. Once upon a time, there was an...             1534
# 18  सभापति महोदय , आपने मुझे महामहिम राष्ट्रपति मह...             1016
# 19  आदरणीय अध्यक्ष महोदय , मैं आपका आभार प्रकट करन...             1237
# 20  At the outset, I am delighted to inform the Ho...              391
# 21  ऑनरेबल स्पीकर साहब , देर से ही सही टाइम तो मिल...             1584
# 22  Vanakkam, Speaker Sir! Thank you for giving me...              475
# 23  महोदय, मैं सबसे पहले महामहिम राष्ट्रपति जी के ...             1563
# 24  I would like to express my views on motion of ...              698
# 25  महामहिम राष्ट्रपति जी के द्वारा संसद में दिए ग...              845
#
#    Language
# 0        hi
# 1        hi
# 2        hi
# 3        hi
# 4        hi
# 5        en
# 6        hi
# 7        en
# 8        hi
# 9        hi
# 10       hi
# 11       hi
# 12       hi
# 13       en
# 14       hi
# 15       en
# 16       en
# 17       en
# 18       hi
# 19       hi
# 20       en
# 21       hi
# 22       en
# 23       hi
# 24       en
# 25       hi

# %%
agg_df.to_csv("aggregated_speeches_05Feb2020.csv", index=False)
